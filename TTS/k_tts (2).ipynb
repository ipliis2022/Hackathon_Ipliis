# %%
from google.colab import drive
drive.mount('/content/drive/myDrive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/k_TTS
# Out:
# /content/drive/MyDrive/k_TTS

# %%
import requests

# 자신의 REST_API_KEY를 입력하세요!
REST_API_KEY = " REST_API_KEY"


class KakaoTTS:

	def __init__(self, text, API_KEY=REST_API_KEY):
		self.resp = requests.post(
			url="https://kakaoi-newtone-openapi.kakao.com/v1/synthesize",
			headers={
				"Content-Type": "application/xml",
				"Authorization": f"KakaoAK {API_KEY}"
			},
			data=f"<speak>{text}</speak>".encode('utf-8')
		)

	def save(self, filename="output.mp3"):
		with open(filename, "wb") as file:
			file.write(self.resp.content)


if __name__ == '__main__':
	tts = KakaoTTS("안녕하세요, 저는 IML이에요.")
	tts.save("output.mp3")

# %%
import requests
# 이지엔 에이스
# 자신의 REST_API_KEY를 입력하세요!
REST_API_KEY = " REST_API_KEY"
#이름
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
이지엔 six 에이스
</prosody>
</voice>

 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
감기로 인한 발열 및 통증, 두통, 신경통, 근육통, 월경통, 염좌통, 삔 통증, 치통, 관절통, 류마트스 통증


</prosody>
</voice>
 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
1회 2캡슐씩 1일 3~4회 (4~6시간마다) 필요시 복용한다.
<break time="150ms"/> 1일 최대 4그램 (12캡슐)을 초과하여 복용하지 않는다. 
<break time="150ms"/>이 약은 가능한 최단기간동안 최소 유효용량으로 복용한다.
</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
다음과 같은 사람은 이 약을 복용하지 말 것 .<break time="150ms"/>
이 약에 과민증 환자, 소화성궤양 환자, 심한 혈액 이상 환자, 심한 간장애 환자, 심한 신장(콩팥)장애 환자, 심한 심장기능저하 환자,<break time="150ms"/> 
아스피린 천식(비스테로이드성 소염(항염)제에 의한 천식발작 유발) 또는 그 병력이 있는 환자, 바르비탈계 약물, 삼환계 항우울제 복용환자,
 알코올을 복용한 사람
</prosody>
</voice>

 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("ace_name.wav")
tts2.save("ace_efficacy.wav")
tts3.save("ace_dosage.wav")
tts4.save("ace_caution.wav")

# %%
#이름
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
이지엔 six 애니 연질캡슐
</prosody>
</voice>

 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
 감기로 인한 발열 및 통증, 요통, 생리통, 류마티양 관절염, 어리거나 젊은나이에 나타나는 류마티양 관절염, 골관절염, 수술후 통증

</prosody>
</voice>
 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
1.<break time="150ms"/>
경증 및 중등도의 통증, 감기<break time="150ms"/>
 성인 1회 200-400mg 1일 삼사회 경구투여한다.
  연령 및 증상에 따라 적절히 증감한다.
2.<break time="150ms"/>
편두통<break time="150ms"/> 성인 1회 200-400mg을 경구투여한다.
 24시간 동안 2캅셀을 초과하지 않도록 한다.
3. <break time="150ms"/>
만 12세 이상 청소년은 1회 200-400mg을 1일 삼사회 경구투여한다. 
<break time="150ms"/>체중이 30kg 미만인경우 1일량이 500mg을 초과해서는 안되며 공복시 투여는 피하는 것이 바람직하다

</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
다음과 같은 사람은 이 약을 복용하지 말 것
<break time="150ms"/ >위장관 궤양, 위장관 출혈환자 또는 그 병력이 있는 환자, 심한 혈액이상 환자,
 심한 간장애 환자, 심한 신장 장애 환자, 심한 심장기능부전 환자, 심한 고혈압 환자, 이 약의 성분에 과민증이 있는 환자, 
 기관지천식 또는 그 병력이 있는 환자
</prosody>
</voice>

 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("EZN6any _name.wav")
tts2.save("EZN6any _efficacy.wav")
tts3.save("EZN6any _dosage.wav")
tts4.save("EZN6any _caution.mp3")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
아진팜 정
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
소화불량, 식욕부진, 과식, 체함, 소화촉진, 소화불량으로 인한 위부팽만감,  변비, 묽은 변, 복부팽만감, 장내이상발효

</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
15세 이상의 성인 1회 1정, 1일 3회
</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
만 7세 이하의 어린이,<break time="150ms"/> 이 약은 유당(젖당)을 함유하고 있으므로, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애등의 유전적인 문제가 있는 환자에게는 투여하면 안 된다.
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("azp_name.wav")
tts2.save("azp_efficacy.wav")
tts3.save("azp_dosage.wav")
tts4.save("azp_caution.wav")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
타이레롤
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
감기로 인한 발열 및 통증, 두통, 신경통, 근육통, 월경통, 염좌통, 치통, 관절통, 류마티스 통증

</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
필요시 1회 1~2정씩 1일 삼사회를 네여섯시간 마다 복용한다. <break time="150ms"/>
1일 최대 4그램 8정을 초과하여 복용하지 않는다.<break time="150ms"/>
 이 약은 가능한 최단기간동안 최소 유효용량으로 복용한다.<break time="150ms"/>
</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
다음과 같은 사람은 이 약을 복용하지 말 것.<break time="150ms"/>
 이 약에 과민증 환자, 소화성궤양 환자, 심한 혈액 이상 환자, <break time="150ms"/>
 심한 간장애 환자, 심한 신장(콩팥)장애 환자, 심한 심장기능저하 환자, <break time="150ms"/>
아스피린 천식 또는 그 병력이 있는 환자나 바르비탈계 약물, 삼환계 항우울제,알코올을 복용한 사람은 약물을 복용해서는 안된다.
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("Tylenol_name.wav")
tts2.save("Tylenol_efficacy.wav")
tts3.save("Tylenol_dosage.wav")
tts4.save("Tylenol_caution.wav")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
라니웰 정
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
위통, 속쓰림, 소화불량, 구역질
</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
1회 2정씩 복용하되 복용 후 5시간 이상 지나도 증상이 완화되지 않으면 다시 2정을 복용하십시오. <break time="150ms"/>
단, 1일 2회 네정을 넘지 않도록 하십시오.<break time="150ms"/>
</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
 혈액질환, 신장ㆍ간장질환, 위ㆍ십이지장질환, 천식ㆍ류마티스 등의 면역계질환으로 치료를 받고 있는 환자는 때때로 백혈구 감소나 혈소판 감소 등이 나타날 수 있습니다.다음 질환으로 치료받고 있는 환자 : 혈액질환, 신장ㆍ간장질환, 위ㆍ십이지장질환, 천식ㆍ류마티스 등의 면역계질환(때때로 백혈구 감소나 혈소판 감소 등이 나타날 수 있습니다. 위ㆍ십이지장질환의 치료를 받고 있는 사람은 라니티딘이나 유사약이 처방되어 있을 가능성이 높기 때문에 중복복용에 조심할 필요가 있습니다
<break time="150ms"/>위ㆍ십이지장질환의 치료를 받고 있는 사람은 라니티딘이나 유사약이 처방되어 있을 가능성이 높기 때문에 중복복용에 조심할 필요가 있습니다.
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("Raniwell_name.wav")
tts2.save("Raniwell_efficacy.wav")
tts3.save("Raniwell_dosage.wav")
tts4.save("Raniwell_caution.wav")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
아이월드 요비신정 
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
방광카타르, 요도염, 신장병, 콩팥증후군, 부종
</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
보통 성인 1회 삼에서 여섯 정, 칠에서 십사세 두,세정을 1일 2회(아침, 저녁) 복용한다.
</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
 다음과 같은 사람은 이 약을 복용하지 말 것<break time="150ms"/>
 6세 이하의 어린이, 
 임부 또는 임신하고 있을 가능성이 있는 여성에게는  약에 함유되어 있는 대황에 의해  자궁수축작용 또는 골반내 장기의 충혈작용에 의해 유·조산의 위험이 있다<break time="150ms"/>
수유부에게는 약에 함유되어 있는 대황중 안트라퀴논 유도체가 모유중으로 이행되어 영아에게 설사를 유발할 수 있으므로 수유중에는 약물복용을 금하거나 수유를 중단한다
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("Yovishin_name.wav")
tts2.save("Yovishin_efficacy.wav")
tts3.save("Yovishin_dosage.wav")
tts4.save("Yovishin_caution.wav")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
페인 엔젤 센연질캡슐
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
류마티양 관절염, 퇴행성 관절질환, 강직성 척추염, 건염, 급성 통풍, 월경곤란증
</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
1. 류마티양 관절염, 골관절염, 강직성 척추염 <break time="150ms"/>
성인<break time="150ms"/> 나프록센으로서 1회 250~500㎎ 1일 2회 경구투여하십시오<break time="150ms"/>

2. 급성통풍<break time="150ms"/>

성인<break time="150ms"/> 나프록센으로서 처음 복용량으로 750㎎을 경구투여하고 발작이 없어질 때까지 8시간간격으로 250㎎을 경구 투여하십시오<break time="150ms"/>

3. 골격근장애, 수술후 통증, 발치 후 통증, 월경곤란증, 건염, 활액낭염<break time="150ms"/>

성인<break time="150ms"/>나프록센으로서 처음 복용량으로 500㎎을 경구투여한 후 여섯시간에서 여덟시간 간격 으로 250㎎씩 투여하십시오. <break time="150ms"/>
1일 총용량이 1,250㎎을 초과하지 않도록 하십시오.

4. 편두통<break time="150ms"/>
성인<break time="150ms"/> 나프록센으로서 초회량[처음 복용량]으로 750㎎을 경구투여 하십시오.

연령 및 증상에 따라 적절히 증감하십시오.


</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
 다음 환자에는 투여하지 마십시오. <break time="150ms"/>
 소화성궤양 환자 ,심한 혈액이상 환자, 심한 간장애 환자, 심한 심기능부전 환자, 심한 신장장애 환자
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("PAXSC_name.wav")
tts2.save("PAXSC_efficacy.wav")
tts3.save("PAXSC_dosage.wav")
tts4.save("PAXSC_caution.wav")

# %%
name = """
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
소하자임플러스정 
</prosody>
</voice>
 
"""
#효과 효능
efficacy ="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
위산과다, 속쓰림, 위부불쾌감, 위부팽만감, 구역, 구토, 위통, 신트림, 소화불량, 식욕감, 과식, 소화촉진, 소화불량으로 인한 위부팽만감

</prosody>
</voice>

 """
#복용방법
dosage="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
성인 1회 2정, 1일 3회 매 식후 복용

</prosody>
</voice>

 """
#주의사항
caution="""
<voice name="WOMAN_READ_CALM"> 
<prosody rate="slow" volume="soft">
다음 환자에는 투여하지 말 것. 투석요법을 받고 있는 환자, 
<break time="150ms"/>이 약은 유당을 함유하고 있으므로, 갈락토오스 불내성, 
<say-as interpret-as="spell-out">Lapp</say-as>유당분해효소 결핍증또는 포도당-갈락토오스 흡수장애등의 유전적인 문제가 있는 환자에게는 투여하면 안된다.<break time="150ms"/>
</prosody>
</voice>
 """
tts1= KakaoTTS(name)
tts2= KakaoTTS(efficacy)
tts3 = KakaoTTS(dosage)
tts4 = KakaoTTS(caution)


tts1.save("Sohazyme_name.wav")
tts2.save("Sohazyme_efficacy.wav")
tts3.save("Sohazyme_dosage.wav")
tts4.save("Sohazyme_caution.wav")
